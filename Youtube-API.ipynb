# %% [markdown]
# #Youtube-API

# %% [markdown]
# Nos dirigimos hacia la página: https://console.cloud.google.com/

# %%
api_key = 'AIzaSyCrw3AabDFEvjVUOSz7oGwmFp5xnlphrGE'

# %% [markdown]
# Para obtener documentacion de la API de google pueden ir a: https://github.com/googleapis/google-api-python-client

# %%
# Instalando libreria
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# En este ejemplo particular usaremos statistics, por si requerimos obtener las estadisticas de algun canal particular

# %%
from googleapiclient.discovery import build
youtube_david= build('youtube','v3',developerKey=api_key)

# %%
request=youtube_david.channels().list(
    part='statistics',
    forUsername= 'schafer5' # puede reemplazarse por cualquiera
)

# %%
response=request.execute()
print(response) # Obtenemos informacion
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': '1MmNlQLQTjeAqgh4s_D_660ngXg', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'npDmDUWP71hy7Y3-vql39JyOgFI', 'id': 'UCCezIgC97PvUuR4_gbFUs5g', 'statistics': {'viewCount': '86183182', 'subscriberCount': '1140000', 'hiddenSubscriberCount': False, 'videoCount': '232'}}]}

# %%
response['pageInfo']
# Out:
# {'totalResults': 1, 'resultsPerPage': 5}

# %%
response['items']
# Out:
# [{'kind': 'youtube#channel',
#   'etag': 'npDmDUWP71hy7Y3-vql39JyOgFI',
#   'id': 'UCCezIgC97PvUuR4_gbFUs5g',
#   'statistics': {'viewCount': '86183182',
#    'subscriberCount': '1140000',
#    'hiddenSubscriberCount': False,
#    'videoCount': '232'}}]

# %%
# Miremos en un canal diferente por ejemplo DW
request2=youtube_david.channels().list(
    part='statistics',
    forUsername= 'sentdex' # puede reemplazarse por cualquiera
)
response2=request2.execute()
print(response2) # Obtenemos informacion
print(response2['items'])
print(response2['pageInfo'])
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'YDbmXxhVdfjrLpNvIMvPS8dx91A', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'Q23IWjfUn3DzDtZ20VinnPLjxMk', 'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ', 'statistics': {'viewCount': '109974805', 'subscriberCount': '1230000', 'hiddenSubscriberCount': False, 'videoCount': '1242'}}]}
# [{'kind': 'youtube#channel', 'etag': 'Q23IWjfUn3DzDtZ20VinnPLjxMk', 'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ', 'statistics': {'viewCount': '109974805', 'subscriberCount': '1230000', 'hiddenSubscriberCount': False, 'videoCount': '1242'}}]
# {'totalResults': 1, 'resultsPerPage': 5}
